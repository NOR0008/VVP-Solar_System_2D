# %%
from Solar_System_2DII import Planet
from Solar_System_2DII import Solar_system
from Solar_System_2DII import json_data
from Solar_System_2DII import random_planets

# %% [markdown]
#     ANIMACE 2: Animace vykresluje 3 planety. Simulace znázorňuje vykreslení místa planet v solárním systému a trajektorie.

# %%
Body3 = Solar_system(json_data('data2D/three_body.json'))
Body3.progressing_simulate(3e5, 1e7)
Body3.draw_place(3e11)

# %%
Body3.draw_way(3e11)

# %%
Body3.animation_planets(5e11)

# %% [markdown]
# Seznam použitých planet:

# %%
json_data('data2D/three_body.json')
# Out:
# [Planet(position=array([-5.60581992e+10, -1.14336280e+11]), velocity=array([-197.9617373 , -107.27019015]), mass=7.434559733701126e+26),
#  Planet(position=array([ 1.14166235e+11, -1.81181201e+10]), velocity=array([-102.96130508,  657.82980586]), mass=2.9566074609778556e+26),
#  Planet(position=array([-2.66374123e+10,  9.76262953e+10]), velocity=array([ 170.91118925, -158.39721176]), mass=3.4325787883158545e+26)]
