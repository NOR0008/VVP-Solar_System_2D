# %% [markdown]
# ANIMACE 3: Nahodné vygenerování planet v solárním systému. V prvním případě se jedná o 3 planety, druhý případ se zabývá pozicí a trajektorií 5 planet.

# %%
from Solar_System_2DII import Planet
from Solar_System_2DII import Solar_system
from Solar_System_2DII import json_data
from Solar_System_2DII import random_planets

# %%
random_planets(3)
# Out:
# [Planet(position=array([-3.57878846e+12,  2.43012131e+12]), velocity=array([ 6834794.42403905, -3208724.29805967]), mass=[6.963869029546095e+22]),
#  Planet(position=array([ 5.03870745e+12, -2.03487157e+12]), velocity=array([-5927020.5284511 ,  6263203.22140821]), mass=[3.129750934967389e+22]),
#  Planet(position=array([-2.16364427e+12,  5.15386087e+12]), velocity=array([-7761589.22995002, -1377230.75536655]), mass=[1.0181700537477953e+21])]

# %%
RunRandom =Solar_system(random_planets(3))
RunRandom.draw_place(3e13)

# %%
RunRandom.progressing_simulate(3e5, 1e7)
RunRandom.animation_planets(2e13)

# %%
random_planets(5)
# Out:
# [Planet(position=array([-5.33935706e+12,  3.20264887e+12]), velocity=array([2516595.77974845, 1463161.25813627]), mass=[6.927868900432416e+22]),
#  Planet(position=array([8.81193038e+12, 9.26243307e+12]), velocity=array([-2192329.40147457,  4603898.83817719]), mass=[9.274545964703187e+22]),
#  Planet(position=array([-2.86623897e+12,  6.62249313e+12]), velocity=array([-9642090.48339238, -7376061.79879315]), mass=[1.0446330741521381e+22]),
#  Planet(position=array([-8.39850283e+12, -7.78627590e+12]), velocity=array([-2055346.8959802 ,  4219745.00434173]), mass=[4.4484157005644043e+21]),
#  Planet(position=array([7.75379046e+12, 5.17607864e+12]), velocity=array([-6417477.71664597,  6763102.8864231 ]), mass=[3.6448491908406056e+22])]

# %%
RunRandom =Solar_system(random_planets(5))
RunRandom.draw_place(1e13)

# %%
RunRandom.progressing_simulate(3e5, 1e7)
RunRandom.animation_planets(3e13)

# %%
RunRandom.draw_way(1e13)
